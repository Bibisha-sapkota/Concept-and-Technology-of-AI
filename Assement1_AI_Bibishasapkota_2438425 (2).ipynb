# %% [markdown]
# 3.1 Problem - 1: Getting Started with Data Exploration

# %% [markdown]
# 1. Load the dataset and display the first 10 rows.

# %%
import pandas as pd
df = pd.read_csv("/WHR-2024-5CS037.csv")
print(df.head(10))#first 10 rows
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %% [markdown]
# 2. Identify the number of rows and columns in the dataset.

# %%
print('rows and columns:', data.shape )
# Out:
# rows and columns: (143, 9)

# %% [markdown]
# 3. List all the columns and their data types.

# %%
print (data.dtypes)
# Out:
# Country name                     object
# score                           float64
# Log GDP per capita              float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# Dystopia + residual             float64
# dtype: object

# %% [markdown]
# #Basic Statistics:
# 1. Calculate the mean, median, and standard deviation for the Score column.

# %%
if 'score' in df.columns:
    mean = df['score'].mean()
    median = df['score'].median()
    std_dev = df['score'].std()

    print("Mean:", mean)
    print("Median:", median)
    print("Standard Deviation:", std_dev)
else:
        print("Column 'score' not found in the dataset.")
# Out:
# Mean: 5.52758041958042
# Median: 5.785
# Standard Deviation: 1.1707165099442995

# %% [markdown]
# 2. Identify the country with the highest and lowest happiness scores.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("/WHR-2024-5CS037.csv")
max_score_country = df.loc[df['score'].idxmax(), 'Country name']
min_score_country = df.loc[df['score'].idxmin(), 'Country name']

print("Country with the highest happiness score:", max_score_country)
print("Country with the lowest happiness score:", min_score_country)
# Out:
# Country with the highest happiness score: Finland
# Country with the lowest happiness score: Afghanistan

# %% [markdown]
# #Missing Values:
# 1. Check if there are any missing values in the dataset. If so, display the total count for each column.

# %%
df = pd.read_csv("/WHR-2024-5CS037.csv")
missing_values = df.isnull().sum()
print("Missing Values for each column:")
print(missing_values)
# Out:
# Missing Values for each column:
# Country name                    0
# score                           0
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# dtype: int64

# %% [markdown]
# #Filtering and Sorting:
# 1. Filter the dataset to show only the countries with a Score greater than 7.5.

# %%
filter =df[df['score'] >7.5]
print(filter)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
#
#    Perceptions of corruption  Dystopia + residual
# 0                      0.546                2.082
# 1                      0.548                1.881
# 2                      0.182                2.050

# %% [markdown]
# 2. For the filtered dataset - Sort the dataset by GDP per Capita in descending order and display the
# top 10 rows.

# %%
top_10_rows = filter.sort_values(by='Log GDP per capita', ascending=False)
print(top_10_rows.head(10))
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 0      Finland  7.741               1.844           1.572
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# 0                    0.695                         0.859       0.142
#
#    Perceptions of corruption  Dystopia + residual
# 1                      0.548                1.881
# 2                      0.182                2.050
# 0                      0.546                2.082

# %% [markdown]
# #Adding New Columns:
# 1. Create a new column called Happiness Category that categorizes countries into three categories
# based on their Score:
#
# Low − (Score < 4)
# Medium − (4 ≤ Score ≤ 6)
# High − (Score > 6)

# %%
def happiness_category(score):
    if score < 4:
        return 'Low'
    elif 4 <= score <= 6:
        return 'Medium'
    else:
        return 'High'

df['happiness_category'] = df['score'].apply(happiness_category)
print(df[['Country name', 'score', 'happiness_category']])
# Out:
#          Country name  score happiness_category
# 0             Finland  7.741               High
# 1             Denmark  7.583               High
# 2             Iceland  7.525               High
# 3              Sweden  7.344               High
# 4              Israel  7.341               High
# ..                ...    ...                ...
# 138  Congo (Kinshasa)  3.295                Low
# 139      Sierra Leone  3.245                Low
# 140           Lesotho  3.186                Low
# 141           Lebanon  2.707                Low
# 142       Afghanistan  1.721                Low
#
# [143 rows x 3 columns]

# %% [markdown]
# #Data Visualizations:
# • Bar Plot: Plot the top 10 happiest countries by Score using a bar chart.
# • Line Plot: Plot the top 10 unhappiest countries by Score using a Line chart.
# • Plot a histogram for the Score column to show its distribution and also interpret.
# • Scatter Plot: Plot a scatter plot between GDP per Capita and Score to visualize their relationship.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
top_10_happycountry = df.sort_values(by='score', ascending=False).head(10)


plt.figure(figsize=(10, 6))
plt.bar(top_10_happycountry['Country name'], top_10_happycountry['score'], color='green')

plt.xlabel('Countrys')
plt.ylabel(' happiness Score')
plt.title('Top 10 Happiest  Countries by Score')

plt.xticks(rotation = 90)
plt.show()

# %%
top_10_unhappiest = df.sort_values(by='score', ascending=True).head(10)

plt.figure(figsize=(10, 6))
sns.lineplot(x='Country name', y='score', data=top_10_unhappiest, marker='o', color='red')
plt.title('Top 10 Unhappiest Countries by Score')
plt.xlabel('Country')
plt.ylabel('Happiness Score')
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
n = len(df)

plt.hist(df['score'], bins=9, color='green', edgecolor='black')
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.title('Score Distribution of happiness')
plt.show()

# %%
plt.scatter(df['Log GDP per capita'], df['score'], color='red', alpha=0.5)
plt.xlabel('Log GDP per capita')
plt.ylabel('Score')
plt.title('Relationship between GDP per Capita and happiness Score')
plt.show()

# %% [markdown]
# #3.2 Problem - 2 - Some Advance Data Exploration

# %% [markdown]
# Define the countries in South Asia with a list for example:
# south asian countries = ["Afghanistan", "Bangladesh", "Bhutan", "India",
#
# "Maldives", "Nepal", "Pakistan", "Srilanka"]

# %%
south_asian_countries = ["Afghanistan", "Bangladesh", "Bhutan", "India","Maldives", "Nepal", "Pakistan", "Srilanka"]

# %% [markdown]
# Use the list from step - 1 to filtered the dataset {i.e. filtered out matching dataset from list.}

# %%
south_asian_countries = ['Afghanistan', 'Bangladesh', 'Bhutan', 'India', 'Maldives', 'Nepal', 'Pakistan', 'Sri Lanka']
filtered_south_asian_data = df[df['Country name'].isin(south_asian_countries)]
print(filtered_south_asian_data)
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 127                    0.586                         0.583       0.144
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
# ...

# %% [markdown]
# 3. Save the filtered dataframe as separate CSV files for future use.

# %%
filtered_south_asian_data.to_csv('filtered_south_asian_data.csv', index=False)
print("Filtered South Asian data saved to 'filtered_south_asian_data.csv'")
# Out:
# Filtered South Asian data saved to 'filtered_south_asian_data.csv'

# %% [markdown]
# #Task - 2 - Composite Score Ranking:

# %% [markdown]
# 1. Using the SouthAsia DataFrame, create a new column called Composite Score that combines the
# following metrics:
#
# Composite Score = 0.40 × GDP per Capita + 0.30 × Social Support
#
# + 0.30 × Healthy Life Expectancy

# %%
filtered_south_asian_data['Composite Score'] = (0.40 * filtered_south_asian_data['Log GDP per capita'] +
                                           0.30 * filtered_south_asian_data['Social support'] +
                                           0.30 * filtered_south_asian_data['Healthy life expectancy'])

print(filtered_south_asian_data)
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 127                    0.586                         0.583       0.144
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
# ...

# %% [markdown]
# 2. Rank the South Asian countries based on the Composite Score in descending order.

# %%
filtered_south_asia = df[df['Country name'].isin(south_asian_countries)]
south_asian_countries_ranked = filtered_south_asia.sort_values(by='score', ascending=False)
print(south_asian_countries_ranked[['Country name', 'score']])
# Out:
#     Country name  score
# 92         Nepal  5.158
# 107     Pakistan  4.657
# 125        India  4.054
# 127    Sri Lanka  3.898
# 128   Bangladesh  3.886
# 142  Afghanistan  1.721

# %% [markdown]
# 3. Visualize the top 5 countries using a horizontal bar chart showing the Composite Score.

# %%
filtered_south_asia = df[df['Country name'].isin(south_asian_countries)]
south_asian_countries_ranked = filtered_south_asia.sort_values(by='score', ascending=False)
top_5_countries = south_asian_countries_ranked.head(5)

plt.figure(figsize=(10, 6))
plt.barh(top_5_countries['Country name'], top_5_countries['score'], color='green')
plt.xlabel('Score')
plt.ylabel('Country')
plt.title('Top 5 South Asian Countries by Score')
plt.show()

# %% [markdown]
# Discuss whether the rankings based on the Composite Score align with the original Score - support your
# discussion with some visualization plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data, replace with your actual data
data = {
    'Country name': ['Country A', 'Country B', 'Country C', 'Country D'],
    'Composite Score': [7.5, 8.2, 6.3, 7.8]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Sort the dataframe by 'Composite Score' in descending order
composite_score_ranked = df.sort_values(by='Composite Score', ascending=False)

# Plotting
plt.figure(figsize=(10, 6))
plt.bar(composite_score_ranked['Country name'], composite_score_ranked['Composite Score'], color='green')
plt.xlabel('Country')
plt.ylabel('Composite Score')
plt.title('Ranking of Countries based on Composite Score')

plt.xticks(rotation=90)
plt.grid(True)
plt.tight_layout()

plt.show()

# %% [markdown]
# #Task - 3 - Outlier Detection:
# Tasks:
# 1. Identify outlier countries in South Asia based on their Score and GDP per Capita.

# %%
q1 = filtered_south_asia['score'].quantile(0.25)
q2 = filtered_south_asia['score'].quantile(0.50)  # Median (second quartile)
q3 = filtered_south_asia['score'].quantile(0.75)

iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

outliers = filtered_south_asia[(filtered_south_asia['score'] < lower_bound) | (filtered_south_asia['score'] > upper_bound)]
print(outliers[['Country name', 'score']])

q1_gdp = filtered_south_asia['Log GDP per capita'].quantile(0.25)
q2_gdp = filtered_south_asia['Log GDP per capita'].quantile(0.50)
q3_gdp = filtered_south_asia['Log GDP per capita'].quantile(0.75)

iqr_gdp = q3_gdp - q1_gdp
lower_bound_gdp = q1_gdp - 1.5 * iqr_gdp
upper_bound_gdp = q3_gdp + 1.5 * iqr_gdp

outliers_gdp = filtered_south_asia[(filtered_south_asia['Log GDP per capita'] < lower_bound_gdp) | (filtered_south_asia['Log GDP per capita'] > upper_bound_gdp)]
print(outliers_gdp[['Country name', 'Log GDP per capita']])
# Out:
#     Country name  score
# 142  Afghanistan  1.721
#     Country name  Log GDP per capita
# 142  Afghanistan               0.628

# %% [markdown]
# 3.Create a scatter plot with GDP per Capita on the x-axis and Score on the y-axis, highlighting outliers
# in a different color.

# %%
q1 = filtered_south_asia['score'].quantile(0.25)
q3 = filtered_south_asia['score'].quantile(0.75)
q1_gdp = filtered_south_asia['Log GDP per capita'].quantile(0.25)
q3_gdp = filtered_south_asia['Log GDP per capita'].quantile(0.75)

iqr_score = q3 - q1
iqr_gdp = q3_gdp - q1_gdp

lower_bound = q1 - 1.5 * iqr_score
upper_bound = q3 + 1.5 * iqr_score
lower_bound_gdp = q1_gdp - 1.5 * iqr_gdp
upper_bound_gdp = q3_gdp + 1.5 * iqr_gdp


outliers = filtered_south_asia[
    (filtered_south_asia['score'] < lower_bound) | (filtered_south_asia['score'] > upper_bound) |
    (filtered_south_asia['Log GDP per capita'] < lower_bound_gdp) | (filtered_south_asia['Log GDP per capita'] > upper_bound_gdp)]

plt.figure(figsize=(10, 6))
plt.scatter(filtered_south_asia['Log GDP per capita'], filtered_south_asia['score'], color='blue', label='Non-Outliers')
plt.scatter(outliers['Log GDP per capita'], outliers['score'], color='red', label='Outliers')
plt.xlabel('Log GDP per Capita')
plt.ylabel('Score')
plt.title('Scatter Plot with Outliers Highlighted')
plt.legend()
plt.show()

# %% [markdown]
# #Task - 4 - Exploring Trends Across Metrics:
# Tasks:
# 1. Choose two metrics (e.g., Freedom to Make Life Choices and Generosity) and calculate their correlation
# {pearson correlation} with the Score for South Asian countries.

# %%
freedom_to_make_life_choices_correlation = filtered_south_asia['Freedom to make life choices'].corr(filtered_south_asia['score'])
generosity_correlation = filtered_south_asia['Generosity'].corr(filtered_south_asia['score'])

print("Correlation between Freedom to Make Life Choices and Score:",freedom_to_make_life_choices_correlation )
print("\nCorrelation between Generosity and Score:", generosity_correlation)
# Out:
# Correlation between Freedom to Make Life Choices and Score: 0.8005185224163315
#
# Correlation between Generosity and Score: 0.874512371253192

# %% [markdown]
# 2.Create scatter plots with trendlines for these metrics against the Score.

# %%
import seaborn as sns
import matplotlib.pyplot as plt



# Scatter plot for 'Freedom to Make Life Choices' vs 'Score'
plt.figure(figsize=(10, 6))
sns.regplot(x='Freedom to make life choices', y='score', data=filtered_south_asia, scatter_kws={'color': 'red'}, line_kws={'color': 'orange'})
plt.title('Scatter Plot of Freedom to Make Life Choices vs Score with Trendline')
plt.xlabel('Freedom to Make Life Choices')
plt.ylabel('Score')
plt.show()

# Scatter plot for 'Generosity' vs 'Score'
plt.figure(figsize=(10, 6))
sns.regplot(x='Generosity', y='score', data=filtered_south_asia, scatter_kws={'color': 'red'}, line_kws={'color': 'orange'})
plt.title('Scatter Plot of Generosity vs Score with Trendline')
plt.xlabel('Generosity')
plt.ylabel('Score')
plt.show()

# %% [markdown]
# #Task - 5 - Gap Analysis:
# Tasks:
# 1. Add a new column, GDP-Score Gap, which is the difference between GDP per Capita and the Score
# for each South Asian country.

# %%
filtered_south_asia['GDP-Score Gap'] = filtered_south_asia['Log GDP per capita'] - filtered_south_asia['score']
print(filtered_south_asia[['Country name', 'Log GDP per capita', 'score', 'GDP-Score Gap']])
# Out:
#     Country name  Log GDP per capita  score  GDP-Score Gap
# 92         Nepal               0.965  5.158         -4.193
# 107     Pakistan               1.069  4.657         -3.588
# 125        India               1.166  4.054         -2.888
# 127    Sri Lanka               1.361  3.898         -2.537
# 128   Bangladesh               1.122  3.886         -2.764
# 142  Afghanistan               0.628  1.721         -1.093
# <ipython-input-184-2d19a28d204e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_south_asia['GDP-Score Gap'] = filtered_south_asia['Log GDP per capita'] - filtered_south_asia['score']

# %% [markdown]
# 2. Rank the South Asian countries by this gap in both ascending and descending order.

# %%
ascending_gap_ranked = filtered_south_asia.sort_values(by='GDP-Score Gap', ascending=True)
descending_gap_ranked = filtered_south_asia.sort_values(by='GDP-Score Gap', ascending=False)
print("Ascending Gap Rank:")
print(ascending_gap_ranked[['Country name', 'GDP-Score Gap']])

print("\nDescending Gap Rank:")
print(descending_gap_ranked[['Country name', 'GDP-Score Gap']])
# Out:
# Ascending Gap Rank:
#     Country name  GDP-Score Gap
# 92         Nepal         -4.193
# 107     Pakistan         -3.588
# 125        India         -2.888
# 128   Bangladesh         -2.764
# 127    Sri Lanka         -2.537
# 142  Afghanistan         -1.093
#
# Descending Gap Rank:
#     Country name  GDP-Score Gap
# 142  Afghanistan         -1.093
# 127    Sri Lanka         -2.537
# 128   Bangladesh         -2.764
# 125        India         -2.888
# 107     Pakistan         -3.588
# 92         Nepal         -4.193

# %% [markdown]
# 3. Highlight the top 3 countries with the largest positive and negative gaps using a bar chart.

# %%
df['GDP-Score Gap'] = df['Log GDP per capita'] - df['score']

ascending_gap_ranked = df.sort_values(by='GDP-Score Gap', ascending=True)
descending_gap_ranked = df.sort_values(by='GDP-Score Gap', ascending=False)

top_3_positive_gap = descending_gap_ranked.head(3)
top_3_negative_gap = ascending_gap_ranked.head(3)

top_3_gap = pd.concat([top_3_positive_gap, top_3_negative_gap])

plt.figure(figsize=(10, 6))
plt.bar(top_3_gap['Country name'], top_3_gap['GDP-Score Gap'], color=['green']*3 + ['red']*3)

plt.title('Top 3 Countries with Largest Positive and Negative Gaps')
plt.xlabel('Country')
plt.ylabel('GDP-Score Gap')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 3.3#**bold text** Problem - 3 - Comparative Analysis:

# %% [markdown]
# 1. Similar in Task - 1 of Problem 2 create a dataframe from middle eastern countries. For hint use the
# following list:
#
#
# middle east countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan",
# "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria",
# "United Arab Emirates", "Yemen"]
#
# Complete the following task:
# 1. Descriptive Statistics:
# • Calculate the mean, Standard deviation of the score for both South Asia and Middle East.
# • Which region has higher happiness Scores on average?

# %%
middle_east_countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan", "Kuwait", "Lebanon", "Oman", "palestine", "Qatar", "Saudi Arabia", "Syria", "United Arab Emirates", "Yemen"]
middle_east_data = df[df['Country name'].isin(middle_east_countries)]

print(middle_east_data)
# Out:
#              Country name  score  Log GDP per capita  Social support  \
# 4                  Israel  7.341               1.803           1.513
# 12                 Kuwait  6.951               1.845           1.364
# 21   United Arab Emirates  6.733               1.983           1.164
# 27           Saudi Arabia  6.594               1.842           1.361
# 61                Bahrain  5.959                 NaN             NaN
# 91                   Iraq  5.166               1.249           0.996
# 99                   Iran  4.923               1.435           1.136
# 124                Jordan  4.186               1.262           0.983
# 132                 Yemen  3.561               0.671           1.281
# 141               Lebanon  2.707               1.377           0.577
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 4                      0.740                         0.641       0.153
# ...

# %%
south_asian_mean = filtered_south_asia['score'].mean()
middle_east_mean = middle_east_data['score'].mean()

south_asian_std = filtered_south_asia['score'].std()
middle_east_std = middle_east_data['score'].std()

print("South Asia Mean:", south_asian_mean)
print("Middle East Mean:", middle_east_mean)

print("\nSouth Asia Standard Deviation:", south_asian_std)
print("Middle East Standard Deviation:", middle_east_std)
# Out:
# South Asia Mean: 3.895666666666667
# Middle East Mean: 5.412100000000001
#
# South Asia Standard Deviation: 1.1770690152521504
# Middle East Standard Deviation: 1.5662011684327144

# %% [markdown]
#  Which region has higher happiness Scores on average?

# %%
if south_asian_mean > middle_east_mean:
    print("South Asia has higher happiness scores on average.")
elif middle_east_mean > south_asian_mean:
    print("Middle East has higher happiness scores on average.")
else:
      print ("Both regions have similar happiness scores on average.")
# Out:
# Middle East has higher happiness scores on average.

# %% [markdown]
# Top and Bottom Performers:
# • Identify the top 3 and bottom 3 countries in each region based on the score.
# • Plot bar charts comparing these charts.

# %%
top_3_south_asian = filtered_south_asia.nlargest(3, 'score')
bottom_3_south_asian = filtered_south_asia.nsmallest(3, 'score')
print("Top 3 Countries in South Asia:")
print(top_3_south_asian[['Country name', 'score']])
print("\nBottom 3 Countries in South Asia:")
print(bottom_3_south_asian[['Country name', 'score']])
# Out:
# Top 3 Countries in South Asia:
#     Country name  score
# 92         Nepal  5.158
# 107     Pakistan  4.657
# 125        India  4.054
#
# Bottom 3 Countries in South Asia:
#     Country name  score
# 142  Afghanistan  1.721
# 128   Bangladesh  3.886
# 127    Sri Lanka  3.898

# %%
top_3_middle_east = middle_east_data.nlargest(3, 'score')
bottom_3_middle_east = middle_east_data.nsmallest(3, 'score')
print("Top 3 Countries in Middle East:")
print(top_3_middle_east[['Country name', 'score']])
print("\nBottom 3 Countries in Middle East:")
print(bottom_3_middle_east[['Country name', 'score']])
# Out:
# Top 3 Countries in Middle East:
#             Country name  score
# 4                 Israel  7.341
# 12                Kuwait  6.951
# 21  United Arab Emirates  6.733
#
# Bottom 3 Countries in Middle East:
#     Country name  score
# 141      Lebanon  2.707
# 132        Yemen  3.561
# 124       Jordan  4.186

# %%
south_asia_top_3 = filtered_south_asia[['Country name', 'score']].sort_values(by='score', ascending=False).head(3)
south_asia_bottom_3 = filtered_south_asia[['Country name', 'score']].sort_values(by='score').head(3)

middle_east_top_3 = middle_east_data[['Country name', 'score']].sort_values(by='score', ascending=False).head(3)
middle_east_bottom_3 = middle_east_data[['Country name', 'score']].sort_values(by='score').head(3)


plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.barplot(x='score', y='Country name', data=south_asia_top_3, hue='Country name', palette='Blues', legend=False)
plt.title('Top 3 Countries in South Asia by Score')
plt.subplot(1, 2, 2)
sns.barplot(x='score', y='Country name', data=south_asia_bottom_3, hue='Country name', palette='Reds', legend=False)
plt.title('Bottom 3 Countries in South Asia by Score')
plt.tight_layout()
plt.show()
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.barplot(x='score', y='Country name', data=middle_east_top_3, hue='Country name', palette='Blues', legend=False)
plt.title('Top 3 Countries in Middle East by Score')
plt.subplot(1, 2, 2)
sns.barplot(x='score', y='Country name', data=middle_east_bottom_3, hue='Country name', palette='Reds', legend=False)
plt.title('Bottom 3 Countries in Middle East by Score')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(top_bottom_south_asia['Country name'], top_bottom_south_asia['score'], color='black')
plt.bar(top_bottom_middle_east['Country name'], top_bottom_middle_east['score'], color='green')
plt.xlabel('Country')
plt.ylabel('Score')

plt.title('Top and Bottom Performers Comparison')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #Metric Comparisons:
# • Compare key metrics like GDP per Capita, Social Support, and Healthy Life Expectancy
# between the regions using grouped bar charts.
# • Which metrics show the largest disparity between the two regions?

# %%
#4
south_asia_score_range = filtered_south_asia['score'].max() - filtered_south_asia['score'].min()
middle_east_score_range = middle_east_data['score'].max() - middle_east_data['score'].min()

south_asia_score_cv = filtered_south_asia['score'].std() / filtered_south_asia['score'].mean()
middle_east_score_cv = middle_east_data['score'].std() / middle_east_data['score'].mean()

print(f"South Asia Score Range: {south_asia_score_range}")
print(f"Middle East Score Range: {middle_east_score_range}")
print(f"South Asia Score CV: {south_asia_score_cv}")
print(f"Middle East Score CV: {middle_east_score_cv}")
# Out:
# South Asia Score Range: 3.4370000000000003
# Middle East Score Range: 4.634
# South Asia Score CV: 0.3021482883337427
# Middle East Score CV: 0.28938880812119405

# %% [markdown]
# :4. Happiness Disparity:
# • Compute the range (max - min) and coefficient of variation (CV) for Score in both regions.
# • Which region has greater variability in happiness?
# 5. Correlation Analysis:
# • Analyze the correlation of Score with other metrics Freedom to Make Life Choices, and
# Generosity within each region.
# • Create scatter plots to visualize and interpret the relationships.
# 6. Outlier Detection:
# • Identify outlier countries in both regions based on Score and GDP per Capita.
# • Plot these outliers and discuss their implications.
# 7. Visualization:
# • Create boxplots comparing the distribution of Score between South Asia and the Middle East.
# • Interpret the key differences in distribution shapes, medians, and outliers.

# %%
#5
import seaborn as sns
import matplotlib.pyplot as plt

# Correlation analysis for South Asia
south_asian_corr = filtered_south_asia[['score', 'Freedom to make life choices', 'Generosity']].corr()
print("South Asia Correlation Matrix:")
print(south_asian_corr)

# Correlation analysis for Middle East
middle_east_corr = middle_east_data[['score', 'Freedom to make life choices', 'Generosity']].corr()
print("Middle East Correlation Matrix:")
print(middle_east_corr)

# Scatter plots for South Asia
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.scatterplot(x='Freedom to make life choices', y='score', data=filtered_south_asia, color='blue')
plt.title('South Asia: Freedom to Make Life Choices vs Score')
plt.xlabel('Freedom to Make Life Choices')
plt.ylabel('Score')

plt.subplot(1, 2, 2)
sns.scatterplot(x='Generosity', y='score', data=filtered_south_asia, color='red')
plt.title('South Asia: Generosity vs Score')
plt.xlabel('Generosity')
plt.ylabel('Score')

plt.tight_layout()
plt.show()

# Scatter plots for Middle East
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.scatterplot(x='Freedom to make life choices', y='score', data=middle_east_data, color='blue')
plt.title('Middle East: Freedom to Make Life Choices vs Score')
plt.xlabel('Freedom to Make Life Choices')
plt.ylabel('Score')

plt.subplot(1, 2, 2)
sns.scatterplot(x='Generosity', y='score', data=middle_east_data, color='red')
plt.title('Middle East: Generosity vs Score')
plt.xlabel('Generosity')
plt.ylabel('Score')

plt.tight_layout()
plt.show()
# Out:
# South Asia Correlation Matrix:
#                                  score  Freedom to make life choices  \
# score                         1.000000                      0.800519
# Freedom to make life choices  0.800519                      1.000000
# Generosity                    0.874512                      0.733396
#
#                               Generosity
# score                           0.874512
# Freedom to make life choices    0.733396
# Generosity                      1.000000
# Middle East Correlation Matrix:
#                                  score  Freedom to make life choices  \
# score                         1.000000                      0.863220
# Freedom to make life choices  0.863220                      1.000000
# Generosity                    0.627524                      0.388854
#
#                               Generosity
# score                           0.627524
# Freedom to make life choices    0.388854
# Generosity                      1.000000

# %%
plt.figure(figsize=(10, 6))
south_asia_data = filtered_south_asia[['Country name', 'score']].copy()
south_asia_data['Region'] = 'South Asia'
middle_east_data = middle_east_data[['Country name', 'score']].copy()
middle_east_data['Region'] = 'Middle East'
combined_data = pd.concat([south_asia_data, middle_east_data])
sns.boxplot(x='Region', y='score', data=combined_data, palette='Set2')
plt.title('Comparison of Happiness Scores Between South Asia and Middle East')
plt.xlabel('Region')
plt.ylabel('Happiness Score')
plt.show()
# Out:
# <ipython-input-37-b52bf3d3ee0c>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Region', y='score', data=combined_data, palette='Set2')
